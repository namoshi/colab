# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/colab/blob/master/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# Example of linear regression
#
# Read the data from file

data1 = read.table("table4.txt", header=TRUE)
print(data1)
# Out:
# Warning message in file(file, "rt"):
# “cannot open file 'table4.txt': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table("table4.txt", header = TRUE)
# 2. file(file, "rt")

# %%
# plot samples
plot(data1$X,data1$Y)
#text(data1$X, data1$Y, labels = seq_along(data1$X), pos=4, col= 'blue')
# Out:
# plot without title

# %%
# linear regression
fit = lm(data1$Y ~ data1$X)

# print the summary of the regression
summary(fit)
# Out:
# Call:
# lm(formula = data1$Y ~ data1$X)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3265 -0.7850 -0.4219  0.8890  2.4120
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  61.8528     1.5878   38.96 2.07e-10 ***
# data1$X       4.5230     0.4252   10.64 5.35e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.471 on 8 degrees of freedom
# Multiple R-squared:  0.934,	Adjusted R-squared:  0.9257
# F-statistic: 113.1 on 1 and 8 DF,  p-value: 5.346e-06

# %%
# draw the regression line
plot(data1$X,data1$Y)
#text(data1$X, data1$Y, labels = seq_along(data1$X), pos=4, col= 'blue')
abline(fit)
# Out:
# plot without title
