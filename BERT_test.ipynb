# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/colab/blob/master/BERT_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers[ja,sentencepiece,torch] pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 30.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 MB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.9/664.9 kB 30.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 MB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 36.6 MB/s eta 0:00:00
# ...
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556704 sha256=9bcdb7f08467d7f3cf0865958a71dc3a49815eeb059bd2e9730aaa3d1875ded2
#   Stored in directory: /root/.cache/pip/wheels/5b/ea/e3/2f6e0860a327daba3b030853fce4483ed37468bbf1101c59c3
# ...

# %%
from transformers import pipeline

# %%
generator = pipeline(
    "text-generation", model="abeja/gpt2-large-japanese"
)

outputs = generator("日本で一番高い山は")
print(outputs[0]["generated_text"])
# Out:
# config.json:   0%|          | 0.00/974 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.04G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/784k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/153 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ...

# %%
outputs = generator("日本で一番高い山は")
print(outputs[0]["generated_text"])
# Out:
# 日本で一番高い山は富士山です。富士山を登ることの素晴らしいところは、日本アルプスを登ることもそうですが、日本アルプスを登るだけで、何万人もの人がいるというところでした。それだけ人が集まる

# %%
import pandas as pd

fill_mask = pipeline(
    "fill-mask", model="cl-tohoku/bert-base-japanese-v3"
)
masked_text = "日本の首都は[MASK]である"
outputs = fill_mask(masked_text)
display(pd.DataFrame(outputs[:3]))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/447M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/231k [00:00<?, ?B/s]
# ...

# %%
masked_text = "今日の映画は刺激的で面白かった．この映画は[MASK]."
outputs = fill_mask(masked_text)
display(pd.DataFrame(outputs[:3]))
# Out:
#       score  token token_str                                 sequence
# 0  0.597188  23845     素晴らしい  今日 の 映画 は 刺激 的 で 面白かっ た. この 映画 は 素晴らしい.
# 1  0.094744  24683       面白い    今日 の 映画 は 刺激 的 で 面白かっ た. この 映画 は 面白い.
# 2  0.064675  26840       楽しい    今日 の 映画 は 刺激 的 で 面白かっ た. この 映画 は 楽しい.
