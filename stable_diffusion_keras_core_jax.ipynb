# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/colab/blob/master/stable_diffusion_keras_core_jax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q keras-cv --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.6/924.6 kB 18.8 MB/s eta 0:00:00

# %%
import os

os.environ["KERAS_BACKEND"] = "jax"

# %%
import keras_cv
import matplotlib.pyplot as plt
# Out:
# Using JAX backend.

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
prompt = "photograph of an astronaut riding a horse"
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
# First run
# %time images = model.text_to_image(prompt, batch_size=3)
# Out:
# ...
# 1356917/1356917 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 492466864/492466864 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ...
# 3439090152/3439090152 ━━━━━━━━━━━━━━━━━━━━ 20s 0us/step
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step
# ...
# 198180272/198180272 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# CPU times: user 4min 31s, sys: 15.2 s, total: 4min 46s
# Wall time: 5min 30s

# %%
# Second run
# %time images = model.text_to_image(prompt, batch_size=3)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step
# CPU times: user 1min 38s, sys: 267 ms, total: 1min 39s
# Wall time: 1min 39s

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)

# %%
prompt = "anime of a japanese girl flying with a small bird"

# %time images = model.text_to_image(prompt, batch_size=3)

plot_images(images)
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 98s 2s/step
# CPU times: user 1min 38s, sys: 235 ms, total: 1min 39s
# Wall time: 1min 40s
