# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.concatenate((np.random.normal(0.0, 1.0, 200),np.random.normal(10.0, 1.0, 1000)))
print(data)

plt.plot(data)
plt.show()
# Out:
# [ 1.87168889 -1.28742809  0.49187815 ... 10.40142075  9.22887244
#  10.46228382]

# %%
def Psi_tanh(x, sigma):
    return np.tanh(x / sigma)

# %%
result = Psi_tanh(data, 20.0)
print(result)

plt.plot(result)
plt.show()
# Out:
# [ 0.09331219 -0.06428264  0.02458895 ...  0.47775484  0.43126007
#   0.48009998]

# %%
# parameters
sigma = 20.0
eta = 0.05
beta = 0.8

theta_list = []
theta = 0.0
diff = 0.0
for i in range(len(data)):
    err = data[i] - theta
    diff = beta * diff - Psi_tanh(err, sigma)
    theta = theta - eta * diff
    theta_list.append(theta)
    
#print(theta_list)
theta_values = np.array(theta_list)
print(theta_values)

plt.plot(data)
plt.plot(theta_values)
plt.show()
# Out:
# [4.66560964e-03 5.17234970e-03 6.79426612e-03 ... 9.98719970e+00
#  9.98678427e+00 9.98764045e+00]
